# %% [markdown]
# <a href="https://colab.research.google.com/github/disakuz/Python_netbooks/blob/main/GOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# https://drive.google.com/file/d/1BLxANjUVeEY_e-kxQZXnqJ4JFKbxWoAz/view?usp=sharing
#
# https://drive.google.com/file/d/1u9LvgkSZF9r7LMVLiALbALRQ_FsxQvmg/view?usp=sharing
#
# https://drive.google.com/file/d/12UjlgMxGuLiB9SEqp8zB-30L3s9W01fI/view?usp=sharing

# %%
# !gdown --id 1BLxANjUVeEY_e-kxQZXnqJ4JFKbxWoAz
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1BLxANjUVeEY_e-kxQZXnqJ4JFKbxWoAz
# To: /content/battles.csv
# 100% 8.55k/8.55k [00:00<00:00, 14.5MB/s]

# %%
# !gdown --id 1u9LvgkSZF9r7LMVLiALbALRQ_FsxQvmg
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1u9LvgkSZF9r7LMVLiALbALRQ_FsxQvmg
# To: /content/character-deaths.csv
# 100% 38.9k/38.9k [00:00<00:00, 49.6MB/s]

# %%
# !gdown --id 12UjlgMxGuLiB9SEqp8zB-30L3s9W01fI
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=12UjlgMxGuLiB9SEqp8zB-30L3s9W01fI
# To: /content/character-predictions.csv
# 100% 216k/216k [00:00<00:00, 89.0MB/s]

# %%
df_d = pd.read_csv('/content/character-deaths.csv')

# %%
df = pd.read_csv('/content/battles.csv')

# %%
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
len(df)
# Out:
# 38

# %%
df.isna().mean()
# Out:
# name                  0.000000
# year                  0.000000
# battle_number         0.000000
# attacker_king         0.052632
# defender_king         0.078947
# attacker_1            0.000000
# attacker_2            0.736842
# attacker_3            0.921053
# attacker_4            0.947368
# defender_1            0.026316
# defender_2            0.947368
# defender_3            1.000000
# defender_4            1.000000
# attacker_outcome      0.026316
# battle_type           0.026316
# major_death           0.026316
# major_capture         0.026316
# attacker_size         0.368421
# defender_size         0.500000
# attacker_commander    0.026316
# defender_commander    0.263158
# summer                0.026316
# location              0.026316
# region                0.000000
# note                  0.868421
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                38 non-null     object
#  1   year                38 non-null     int64
#  2   battle_number       38 non-null     int64
#  3   attacker_king       36 non-null     object
#  4   defender_king       35 non-null     object
#  5   attacker_1          38 non-null     object
#  6   attacker_2          10 non-null     object
#  7   attacker_3          3 non-null      object
#  8   attacker_4          2 non-null      object
#  9   defender_1          37 non-null     object
#  10  defender_2          2 non-null      object
#  11  defender_3          0 non-null      float64
#  12  defender_4          0 non-null      float64
#  13  attacker_outcome    37 non-null     object
#  14  battle_type         37 non-null     object
# ...

# %%
len(df['name'].unique())
# Out:
# 38

# %%
df.groupby('attacker_king')['battle_number'].agg('count').sort_values(ascending = False)
# Out:
# attacker_king
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: battle_number, dtype: int64

# %%
df.groupby('defender_king')['battle_number'].agg('count').sort_values(ascending = False)
# Out:
# defender_king
# Robb Stark                  14
# Joffrey/Tommen Baratheon    13
# Balon/Euron Greyjoy          4
# Stannis Baratheon            2
# Mance Rayder                 1
# Renly Baratheon              1
# Name: battle_number, dtype: int64

# %% [markdown]
# Главные драчуны Старки и Баратеоны

# %%
df['attacker_size'].fillna(0,inplace=True)

# %%
df['defender_size'].fillna(0,inplace=True)

# %%
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
df.groupby('name')['attacker_size','defender_size'].sum().sort_values('attacker_size',ascending = False)
# Out:
# <ipython-input-16-d7f769b53b53>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('name')['attacker_size','defender_size'].sum().sort_values('attacker_size',ascending = False)
#                                                     attacker_size  \
# name
# Battle of Castle Black                                   100000.0
# Battle of the Blackwater                                  21000.0
# Battle of the Fords                                       20000.0
# Battle of the Green Fork                                  18000.0
# Battle of Riverrun                                        15000.0
# Battle of the Golden Tooth                                15000.0
# Battle of Oxcross                                          6000.0
# Battle of the Camps                                        6000.0
# Battle of the Crag                                         6000.0
# ...

# %% [markdown]
# Battle of Castle Black самая групномасштабная битва, в которой было больше всего нападающих

# %%
df['sum_solders'] = df['attacker_size'] + df['defender_size']

# %%
df.groupby('name')['sum_solders'].sum().sort_values(ascending = False)
# Out:
# name
# Battle of Castle Black                                  101240.0
# Battle of the Green Fork                                 38000.0
# Battle of the Fords                                      30000.0
# Battle of the Blackwater                                 28250.0
# Siege of Storm's End                                     25000.0
# Battle of Riverrun                                       25000.0
# Battle of the Golden Tooth                               19000.0
# Battle of the Camps                                      18625.0
# Battle of Oxcross                                        16000.0
# Siege of Winterfell                                      13000.0
# Battle of the Whispering Wood                             7875.0
# The Red Wedding                                           7000.0
# Battle of the Crag                                        6000.0
# Battle of the Ruby Ford                                   6000.0
# ...

# %%
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_capture  attacker_size  \
# 0        NaN        NaN      Tully  ...           0.0        15000.0
# ...

# %%
df.fillna('no_info', inplace = True)

# %%
df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister    no_info
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister    no_info
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister    no_info
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark    no_info
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_capture attacker_size  \
# 0    no_info    no_info      Tully  ...           0.0       15000.0
# ...

# %%
df_d.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)             None       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
df.groupby('year',as_index=False).sum()
# Out:
#    year  battle_number  attacker_size  defender_size  sum_solders
# 0   298             28        55875.0        52745.0     108620.0
# 1   299            350        66746.0        59750.0     126496.0
# 2   300            363       116000.0         9640.0     125640.0

# %%
df.loc[df['battle_number'] == 28]
# Out:
#                       name  year  battle_number      attacker_king  \
# 27  Battle of Castle Black   300             28  Stannis Baratheon
#
#    defender_king attacker_1 attacker_2 attacker_3 attacker_4     defender_1  \
# 27  Mance Rayder  Free folk     Thenns     Giants    no_info  Night's Watch
#
#     ... major_capture attacker_size defender_size  \
# 27  ...           1.0      100000.0        1240.0
#
#                                    attacker_commander  \
# 27  Mance Rayder, Tormund Giantsbane, Harma Dogshe...
#
#                                    defender_commander summer      location  \
# 27  Stannis Baratheon, Jon Snow, Donal Noye, Cotte...    0.0  Castle Black
#
#              region     note sum_solders
# 27  Beyond the Wall  no_info    101240.0
#
# [1 rows x 26 columns]

# %%
df_p = pd.read_csv('/content/character-predictions.csv')

# %%
df_p.head()
# Out:
#    S.No  actual  pred  alive   plod                  name  \
# 0     1       0     0  0.054  0.946  Viserys II Targaryen
# 1     2       1     0  0.387  0.613           Walder Frey
# 2     3       1     0  0.493  0.507          Addison Hill
# 3     4       0     0  0.076  0.924           Aemma Arryn
# 4     5       1     1  0.617  0.383        Sylva Santagar
#
#                   title  male   culture  dateOfBirth  ...  isAliveHeir  \
# 0                   NaN     1       NaN          NaN  ...          0.0
# 1  Lord of the Crossing     1  Rivermen        208.0  ...          NaN
# 2                   Ser     1       NaN          NaN  ...          NaN
# 3                 Queen     0       NaN         82.0  ...          NaN
# 4            Greenstone     0   Dornish        276.0  ...          NaN
#
#   isAliveSpouse isMarried isNoble   age numDeadRelations  boolDeadRelations  \
# 0           NaN         0       0   NaN               11                  1
# ...
